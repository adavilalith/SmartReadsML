# %%
import numpy as np
import pandas as pd
import pickle

# %%
pt = pickle.load(open('../backend/res/pt.pkl','rb'))
books = pickle.load(open('../backend/res/books.pkl','rb'))
scores = pickle.load(open('../backend/res/scores.pkl','rb'))

# %%
len(np.where(pt.index=='Animal Farm')[0])
# Out:
# 1

# %%
sorted(list(enumerate(scores[47])),key=lambda x:x[1],reverse=True)
# Out:
# [(47, 0.9999999999999999),
#  (0, 0.26331668558969296),
#  (45, 0.2416404696056939),
#  (324, 0.2362570952024308),
#  (422, 0.21897040971615078),
#  (92, 0.20936355536567294),
#  (344, 0.2039361513890485),
#  (309, 0.20012818613438033),
#  (501, 0.1992002995217232),
#  (82, 0.1934411223332458),
#  (696, 0.1933680785174527),
#  (86, 0.1853698575738056),
#  (651, 0.1818386353412456),
#  (238, 0.1808593793358965),
#  (389, 0.18033685629548887),
#  (304, 0.1785762436501139),
#  (175, 0.17810293434375038),
#  (649, 0.17616468525883922),
#  (40, 0.17574683842508246),
#  (178, 0.17550919073101653),
#  (432, 0.17524780797774),
#  (611, 0.17285553764932207),
#  (19, 0.17139647009659337),
#  (192, 0.1687005636608251),
#  (508, 0.16443208359268566),
#  (156, 0.16082459779343755),
#  (202, 0.16077267549550414),
#  (692, 0.15870304913591407),
#  (5, 0.15866348262730293),
#  (312, 0.1565007975327465),
#  (668, 0.15632476361389702),
#  (627, 0.1548168121432704),
#  (384, 0.15260868572873312),
# ...

# %%
pt.index[324]
# Out:
# 'Midnight'

# %%
pt[47]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 47
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ...
